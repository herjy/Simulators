# %% [markdown]
# # Dataframe creation using the Hsiao class

# %% [markdown]
# Example notebook showing how to obtain dataframes of generated data (flux and time sample) of supernova 1a by defining some parameters.

# %%
from hsiao import Hsiao
import numpy as np
import pandas as pd
import random as rand
from random import *
import time

# %% [markdown]
# ### Example of return datafram from Hsiao class for 1 system of 3 images.

# %%
#Hsiao(nb of images, redshift, amplitude, type of plot, magnifications, time delays, time origin, noise level)

# nb of images, time origin are integers
# redshift, amplitude, noise level are floats
# type of plot is a str (choice bewteen : "Flux", "Total_Flux_Without_Noise", "Noise", "Total_Flux_With_Noise")
# magnifications, time delays are arrays of size (nb of images)

H=Hsiao(3, 0.4, 1e-4, "Flux", np.array([1.2, 1.42, 1.52]), np.array([0, 10.34, 24.32]), 55000., 0.05)

# %% [markdown]
# The dataframe method from Hsiao class returns 2 different dataframes:
# - the first contains all the given information from the user, e.i all the above parameters
# - the second is composed of generated data calculated into Hsiao class.
#
# To match the first dataframe with the second one, an ID is defined and written in the first column of each dataframe. It is created thanks to the number of images, the amplitude, the redshift and the noise level to make sure there are no duplicates.

# %%
f1, f2 = H.dataframe()

# %%
f1
# Out:
#                   ID images time origin amplitude          time delays  \
# 0  3-0.0001-0.4-0.05      3     55000.0    0.0001  [ 0.   10.34 24.32]
#
#      magnifications redshift noise level
# 0  [1.2  1.42 1.52]      0.4        0.05

# %%
f2
# Out:
#                    ID  time sample band g  total flux + noise band g  \
# 0   3-0.0001-0.4-0.05            54942.48                  16.122651
# 1   3-0.0001-0.4-0.05            54945.28                  22.858027
# 2   3-0.0001-0.4-0.05            54948.08                  26.104037
# 3   3-0.0001-0.4-0.05            54948.88                  15.867746
# 4   3-0.0001-0.4-0.05            54951.68                  -1.070113
# ..                ...                 ...                        ...
# 86  3-0.0001-0.4-0.05            55113.28                  30.231925
# 87  3-0.0001-0.4-0.05            55114.08                  16.914728
# 88  3-0.0001-0.4-0.05            55116.88                  17.113194
# 89  3-0.0001-0.4-0.05            55119.68                  18.867746
# 90  3-0.0001-0.4-0.05            55121.48                  29.845606
#
#     time sample band r  total flux + noise band r  time sample band i  \
# 0             54941.48                  14.789232            54945.88
# 1             54943.28                   9.071923            54953.08
# 2             54945.08                   9.026746            54958.28
# 3             54946.88                  17.654394            54960.48
# 4             54948.68                  14.317853            54961.68
# ..                 ...                        ...                 ...
# 86            55109.28                  42.743771                 NaN
# 87            55111.08                  29.574207                 NaN
# 88            55114.88                  37.082171                 NaN
# 89            55115.68                  29.404348                 NaN
# 90                 NaN                        NaN                 NaN
#
#     total flux + noise band i
# 0                   13.618154
# 1                   13.987194
# 2                   19.280764
# 3                   48.333877
# 4                  116.044908
# ..                        ...
# 86                        NaN
# 87                        NaN
# 88                        NaN
# 89                        NaN
# 90                        NaN
#
# [91 rows x 7 columns]

# %% [markdown]
# ### Example of dataframe with multiple systems.

# %% [markdown]
# First, the time delays need to be defined such as the first is null and the others are increasing.

# %%
def delays(n):
    DT = [0]
    for i in range(1, n):
        DT.append(DT[i-1] + uniform(5, 15))
    return [round(num, 4) for num in DT]

# %% [markdown]
# Secondly, to create dataframes containing 20 systems, the parameters are calculated randomly or followinf a unifrom distribution.
# Then, the produced dataframe are concatenate and we obtain 2 dataframes with one composed of all the parameters, and the second the generated data.

# %%
start = time.time()

f1 = 0
f2 = 0
f1bis = 0
f2bis = 0
i=0

while i<10000:
    nb_images = rand.choice([1, 2, 3, 4])  #(to maximize non lensed supernova)
    redshift = np.around(uniform(1, 2.5), 4)      # do not put more than 2.5
    amplitude = np.around(uniform(1e-5, 1e-1),4)
    mu = [1 + np.around(rand.random(), 4) for i in range(nb_images)]
    #print(nb_images, mu)
    time_delays = delays(nb_images)
    #t0 = np.random.randint(55000, 60000)
    t0 = 55000.      #if not, fluxes = csts -> why ? (maybe) because of the def of Hsiao model
    noise_level = np.around(uniform(0, 0.2), 4)
    H = Hsiao(nb_images, redshift, amplitude, "Flux", np.array(mu), np.array(time_delays), t0, noise_level, nobs = np.array([91, 91, 91]), ID= i)

    if i == 0:
        f1bis, f2bis = H.dataframe()
        i+=1
    else:
        f1, f2 = H.dataframe()
        
        if f2.isnull().values.any()==False:
            f1 = pd.concat([f1bis, f1])
            f2 = pd.concat([f2bis, f2])
            f1bis = f1
            f2bis = f2
            i+=1
end = time.time()
print("The time of execution of above program is :", end-start)
# Out:
# /Users/lea/repositories/Simulators/Hsiao/hsiao.py:166: RuntimeWarning: All-NaN slice encountered
#   noises = np.full((len(self.bands), max(self.nobs)), self.pers*np.nanmax(self.total_flux_without_noise()))
# The time of execution of above program is : 428.48359394073486

# %%
check_for_nan = f1.isnull().values.any()
print (check_for_nan)
# Out:
# False

# %%
check_for_nan = f2.isnull().values.any()
print (check_for_nan)
# Out:
# False

# %%
f1
# Out:
#       ID images time origin amplitude                time delays  \
# 0      0      1     55000.0    0.0795                        [0]
# 0      1      4     55000.0    0.0019  [ 0.   14.73 23.36 36.26]
# 0      2      3     55000.0    0.0118        [ 0.    7.65 14.81]
# 0      3      3     55000.0    0.0154        [ 0.    6.63 14.93]
# 0      4      4     55000.0    0.0132  [ 0.    5.12 19.52 27.45]
# ..   ...    ...         ...       ...                        ...
# 0   9995      2     55000.0      0.07              [ 0.   13.76]
# 0   9996      3     55000.0    0.0243        [ 0.    6.47 18.15]
# 0   9997      3     55000.0    0.0466        [ 0.   10.09 18.89]
# 0   9998      4     55000.0    0.0827  [ 0.    9.51 19.54 27.8 ]
# 0   9999      3     55000.0    0.0513        [ 0.    5.27 17.83]
#
#            magnifications redshift noise level
# 0                  [1.96]   1.6957      0.1676
# 0   [1.21 1.9  1.42 1.23]   1.3082      0.0226
# 0        [1.75 1.41 1.74]   1.0825      0.0083
# 0        [1.42 1.31 1.64]   1.7082      0.1389
# 0   [1.04 1.74 1.53 1.75]   1.3018      0.1011
# ..                    ...      ...         ...
# 0             [1.14 1.32]    1.994      0.1515
# 0        [1.71 1.13 1.43]    2.134      0.1931
# 0        [1.22 1.52 1.11]   1.4547      0.0105
# 0   [1.28 1.74 1.92 1.  ]   1.1192      0.1787
# 0        [1.31 1.78 1.16]   1.1507      0.1369
#
# [10000 rows x 8 columns]

# %%
f2[:91]
# Out:
#     ID  images  time sample band g  total flux + noise band g  \
# 0    0       1             54965.8                9857.548565
# 1    0       1             54966.6               10549.269195
# 2    0       1             54967.4               16872.628352
# 3    0       1             54970.2               12590.366603
# 4    0       1             54972.0               13184.015601
# ..  ..     ...                 ...                        ...
# 86   0       1             55125.6                3499.687284
# 87   0       1             55126.4                4783.304837
# 88   0       1             55127.2                9358.904012
# 89   0       1             55130.0                8613.177603
# 90   0       1             55130.8                6774.703362
#
#     time sample band r  total flux + noise band r  time sample band i  \
# 0              54966.8               12808.463139             54969.2
# 1              54967.6               14277.550934             54974.4
# 2              54968.4               11533.402431             54978.6
# 3              54969.2               20060.419435             54983.8
# 4              54972.0               12283.637781             54989.0
# ..                 ...                        ...                 ...
# 86             55120.6                3493.996352             55424.4
# 87             55122.4               12600.181485             55428.6
# 88             55123.2               10744.485320             55430.8
# 89             55126.0                3692.878634             55438.0
# 90             55126.8                6814.146740             55443.2
#
#     total flux + noise band i
# 0                46451.732114
# 1                70732.207850
# 2                78989.423208
# 3                78834.373466
# 4               106359.738547
# ..                        ...
# 86               15596.422526
# 87                2834.043979
# 88                9900.469006
# 89               10380.532886
# 90               16155.818350
#
# [91 rows x 8 columns]

# %%
f1.to_csv("truth.csv", index=False)
f2.to_csv("data.csv", index=False)

# %% [markdown]
# ### Example of dataframe with flux without noise.

# %%
start = time.time()

f1 = 0
f2 = 0
f1bis = 0
f2bis = 0
i=0

while i<10000:
    nb_images = rand.choice([1, 2, 3, 4])  #(to maximize non lensed supernova)
    redshift = np.around(uniform(1, 2.5), 4)      # do not put more than 2.5
    amplitude = np.around(uniform(1e-5, 1e-1),4)
    mu = [1 + np.around(rand.random(), 4) for i in range(nb_images)]
    time_delays = delays(nb_images)
    #t0 = np.random.randint(55000, 60000)
    t0 = 55000.      #if not, fluxes = csts -> why ? (maybe) because of the def of Hsiao model
    noise_level = np.around(uniform(0, 0.2), 4)
    H = Hsiao(nb_images, redshift, amplitude, "Flux", np.array(mu), np.array(time_delays), t0, noise_level, nobs = np.array([91, 91, 91]), ID= i)

    if i == 0:
        f1bis, f2bis = H.dataframeF()
        i+=1
    else:
        f1, f2 = H.dataframeF()
        
        if f2.isnull().values.any()==False:
            f1 = pd.concat([f1bis, f1])
            f2 = pd.concat([f2bis, f2])
            f1bis = f1
            f2bis = f2
            i+=1
end = time.time()
print("The time of execution of above program is :", end-start)

# %%
f1.to_csv("truthF.csv", index=False)
f2.to_csv("dataF.csv", index=False)
